# %% [markdown]
# # DCGAN in theory and practice

# %%
import altair as alt
import numpy as np
import tensorflow as tf

tfgan = tf.contrib.gan

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Theory" data-toc-modified-id="Theory-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Theory</a></span><ul class="toc-item"><li><span><a href="#Enter-DCGAN" data-toc-modified-id="Enter-DCGAN-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Enter DCGAN</a></span></li><li><span><a href="#Generator:-from-noise-to-insight" data-toc-modified-id="Generator:-from-noise-to-insight-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Generator: from noise to insight</a></span><ul class="toc-item"><li><span><a href="#Deconvolution" data-toc-modified-id="Deconvolution-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Deconvolution</a></span></li><li><span><a href="#Batch-Normalization" data-toc-modified-id="Batch-Normalization-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Batch Normalization</a></span></li><li><span><a href="#generator_fn()" data-toc-modified-id="generator_fn()-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>generator_fn()</a></span></li></ul></li><li><span><a href="#Discriminator" data-toc-modified-id="Discriminator-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Discriminator</a></span><ul class="toc-item"><li><span><a href="#discriminator_fn()" data-toc-modified-id="discriminator_fn()-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>discriminator_fn()</a></span></li></ul></li><li><span><a href="#Loss-function:-a-bridge-between-two-networks" data-toc-modified-id="Loss-function:-a-bridge-between-two-networks-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Loss function: a bridge between two networks</a></span></li></ul></li><li><span><a href="#Practice---Introduction" data-toc-modified-id="Practice---Introduction-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Practice - Introduction</a></span><ul class="toc-item"><li><span><a href="#Input-Functions" data-toc-modified-id="Input-Functions-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Input Functions</a></span><ul class="toc-item"><li><span><a href="#Loading-Images" data-toc-modified-id="Loading-Images-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Loading Images</a></span></li></ul></li><li><span><a href="#Hyperparameters" data-toc-modified-id="Hyperparameters-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Hyperparameters</a></span></li><li><span><a href="#Training" data-toc-modified-id="Training-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Training</a></span></li><li><span><a href="#TensorBoard" data-toc-modified-id="TensorBoard-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>TensorBoard</a></span></li></ul></li><li><span><a href="#NOTES" data-toc-modified-id="NOTES-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>NOTES</a></span></li><li><span><a href="#Links" data-toc-modified-id="Links-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Links</a></span></li></ul></div>

# %% [markdown]
# ## Theory

# %% [markdown]
# ### Enter DCGAN

# %% [markdown]
# ![DCGAN](images/dcgan.png)
#
# If you take a look at an [impressive list of GANs](), you see that DCGAN, the architecture of our choice, is just a small drop in the ocean. While there may be sexier ones, very few offers the same package of clarity, stability, performances and computational efficiency, these are the main one reason why DCGAN is considered one of the cornerstones of this field.
#
# Proposed in a 2015 paper by Alec Radford, Luke Metz, Soumith Chintala, the idea behind DCGAN is quite straightforward: combining a set of architectural constraints with the power of CNN yields us a robust, stable, and competitive model. Succeeding where many others failed, the authors present us with a simple model, asymmetrical architecture, 4 deconvolutional layers at the Generator with 4 layers of convolution at the Discriminator with the following constraints:
#
# - All pooling layers are replaced with stranded convolutions (discriminator) and fractional-stride convolutions (generator).
# - Batch-normalization used in both networks.
# - Removal of fully connected layers (except for the discriminator output)
# - `ReLU` for all Generator layers except the output, which uses `tanh`.
# - `LeakyReLU` activation in the discriminator for all layers.
#
# While there are have been very recent advancements in state of the art (i.e., CoordConv, Spectral Normalization), we felt that before venturing into the bleediest of the edges it is essential to have a firm understanding of the basic concept. We leave you (an opinionated) list of further resources you can use to get up to speed to the most exciting line of research.

# %% [markdown]
# ### Generator: from noise to insight
#
# ![DCGAN Generator](images/dcgan_generator.png)
#
# If you recall the theoretical explanation, the Generator is the network responsible for the data-generation, learning how to fool its discriminator allows it to produce realistic results "sampled' from the learned manifold.
#
# The most common type of generator_inputs is pure and straightforward noise; however, more specialized GANs may require additional parameters. Since our full-demo uses a Deep Convolutional GAN (DCGAN), we don't need any other parameters.

# %% [markdown]
# #### Deconvolution
#
# > When we have neural networks generate images, we often have them build them up from low resolution, high-level
# > descriptions. This allows the network to describe the rough image and then fill in the details.
# >
# > In order to do this, we need some way to go from a lower resolution image to a higher one. We generally do this with the deconvolution operation.
# > Roughly, deconvolution layers allow the model to use every point in the small image to “paint” a square in the larger one.
#
# We have implemented the deconvolution layers following the findings explained [here]().
#
# The core idea behind the paper is that boundaries and checkerboards artifacts are not due the adversarial training but are inherent to the deconvolution process, to tackle this issue, the suggested solution is an improved version of the upsampling operation, called the **different resize-convolution** whose core is a resize operation powered by either **nearest-neighbor interpolation** or **bilinear interpolation**.
#
# As in the paper, we are going with the ** nearest-neighbor** one.

# %%
def deconv2d(inputs, filters, strides=(1, 1), activation=tf.nn.relu):
    """\"Deconvolution\" layer.
    
    It uses upsampling with nearest neighbor interpolation to reduce the
    presence of checkboard artifacts.
    """
    
    input_h, input_w = inputs.shape[1].value, inputs.shape[2].value
    layer_1 = tf.image.resize_nearest_neighbor(
        inputs, (2 * input_h, 2 * input_w), name="NNUpSample2D"
    )
    # Padding before convolution is used to reduce boundary artifacts
    layer_1 = tf.pad(layer_1, [[0, 0], [2, 2], [2, 2], [0, 0]], mode="CONSTANT")
    layer_2 = tf.layers.conv2d(
        inputs=layer_1,
        filters=filters,
        kernel_size=5,
        padding="valid",
        use_bias=False,
        activation=activation,
        strides=strides,
    )
    return layer_2

# %% [markdown]
# #### Batch Normalization
#
# We do not enter into the theoretical depth of `BatchNorm` as the discussion on why or whether it works it's still open and going [NOTE 1](). What you need to know is that TensorFlow makes it very easy to implement such an operation.
#
# ```python
# tf.layers.batch_normalization(input, training=is_training)
# ```

# %% [markdown]
# #### generator_fn()

# %%
def generator_fn(inputs, mode):
    """Generator producing images from noise.
        Args:
            noise: A single Tensor representing noise.
            mode: Either TRAIN, EVAL or PREDICT
        Returns:
            A 64x64 (None, 4096) flattened tensor whose values are
            inside the (-1, 1) range."""
    is_training = mode == tf.estimator.ModeKeys.TRAIN
    linear = tf.layers.dense(inputs=inputs, units=1024 * 4 * 4, activation=tf.nn.relu)
    net = tf.reshape(linear, (-1, 4, 4, 1024))
    net = tf.layers.batch_normalization(net, training=is_training)
    net = deconv2d(net, 512)
    net = tf.layers.batch_normalization(net, training=is_training)
    net = deconv2d(net, 256)
    net = tf.layers.batch_normalization(net, training=is_training)
    net = deconv2d(net, 128)
    net = tf.layers.batch_normalization(net, training=is_training)
    net = deconv2d(net, 64)
    net = tf.layers.conv2d(
        inputs=net,
        filters=3,
        kernel_size=5,
        padding="same",
        data_format="channels_last",
        use_bias=False,
        strides=(1, 1),)
    output = tf.tanh(net)
    print(output)
    return output

# %% [markdown]
# ### Discriminator
#
# ![DCGAN Discriminator](images/dcgan_discriminator.png)
#
# As for the `input_fn()` we can reuse all the code we defined for the vanilla `Estimator` describing the discriminator network architecture.

# %% [markdown]
# #### discriminator_fn()

# %%
def conv2d(inputs, filters, strides=(2,2)):
    """Helper layer used to instatiate `tf.layers.conv2d` with proper arguments."""
    layer_1 = tf.layers.conv2d(
        inputs=inputs,
        filters=filters,
        kernel_size=5,
        padding="same",
        data_format="channels_last",
        use_bias=False,
        strides=strides,
    )
    layer_1 = tf.nn.leaky_relu(layer_1, alpha=0.2)

    return layer_1

# %%
def discriminator_fn(inputs, conditioning, mode):
    """Build the Discriminator network.
    Args:
        features: a batch of images to classify, expected input shape (None, 64, 64 , 3)
        labels: a batch of labels
        mode: the tf.estimator.ModeKey
        params: a dict of optional parameters
    Returns:
            The output (logits) of the discriminator.
    """
    
    # In every mode, define the model
    is_training = mode == tf.estimator.ModeKeys.TRAIN
    net = conv2d(inputs, filters=128)
    net = tf.layers.batch_normalization(net, training=is_training)
    net = conv2d(net, filters=256)
    net = tf.layers.batch_normalization(net, training=is_training)
    net = conv2d(net, filters=512)
    net = tf.layers.batch_normalization(net, training=is_training)
    net = conv2d(net, filters=1024)
    net = tf.layers.batch_normalization(net, training=is_training)
    net = tf.reshape(net, (-1, net.shape[1] * net.shape[2] * net.shape[3]))
    net = tf.layers.dense(net, units=1)
    out = tf.identity(net)
    
    return out

# %% [markdown]
# ### Loss function: a bridge between two networks

# %% [markdown]
# There are a lot of loss functions usable in GANs'architectures from very domain-specific ones to ones that are perfect for general use cases. Since our goal here falls in the latter category, we use the so-called ** Non-Saturating Loss** which is the non-saturating variant of the **MinMax Loss** proposed by Goodfellow in the [original paper]().
#
# As stated earlier, one of the beauties of `TFGAN` is its offerings losses ready for use, if you cannot find the loss you want, you can create your own (though this topic is outside the scope of this workshop, we leave an example of a low-level re-implementation of the `NS MinMax` in the **Beyond the Basics** section).
#
# We use the following two losses:
#
# ```python
# generator_loss_fn=tfgan.losses.minimax_generator_loss
#
# discriminator_loss_fn=tfgan.losses.minimax_discriminator_loss
# ```
#
# It is that easy.

# %% [markdown]
# ## Practice - Introduction
#
# Having seen the general structure of the TFGAN library, we dive right into the model architecture.
#
# In our showcasing of the TensorFlow API, we have built an image recognition network, GANs, however, require the training of both a Generator and a Discriminator together. While this task is either verbose and possibly performance-constrained (in the case of writing it in vanilla TensorFlow) or complicated (Estimator API) thanks to GANEstimator it becomes remarkably simple.

# %% [markdown]
# ### Input Functions
#
# The input function for the `GANEstimator` is very much the same as the one we would define for a normal `tf.Estimator`.
#
#
# >    The function should construct and return one of the following:
# >
# >    A tf.data.Dataset object: Outputs of Dataset object must be a tuple (features, labels) with same constraints as below.
# >
# >    A tuple (features, labels): Where `features` is a Tensor or a dictionary of string feature name to Tensor and >`labels` is a Tensor or a dictionary of string label name to Tensor. Model_fn consumes both features and labels. They should satisfy the expectation of model_fn from inputs.
#
#
# We write our input function following the style and structure presented available on [TensorFlow Models](#1) as an example.
#
# > ```python
# def _get_train_input_fn(batch_size, noise_dims, dataset_dir=None,
#                         num_threads=4):
#   def train_input_fn():
#     with tf.device('/cpu:0'):
#       images, _, _ = data_provider.provide_data(
#           'train', batch_size, dataset_dir, num_threads=num_threads)
#     noise = tf.random_normal([batch_size, noise_dims])
#     return noise, images
# return train_input_fn
# >```
#
# The two main ideas to take from this are:
#
# 1. structure the code in the same way, the `GANEstimator` wants **function objects** as inputs thus the need to wrap them.
# 2. Return **noise** first and then the **real_data** (here called `images`) and optionally **labels**.
# 3. **EXP:** while often you want to work with **features (and labels)** fetched from a `tf.Dataset` [see REFERENCE](), the **noise** should always be instantiated using a simple TensorFlow node. Trying to create a noise-containing `tf.Dataset` for the `train_input_fn` is not worth the effort. NOTE: that as [we will see later](), things are different for the`_get_predict_input_fn`.

# %% [markdown]
# #### Loading Images
#
# We reuse the same `input_fn()` we defined earlier with minor changes in order to make it consistent with the aforementioned code strfucture.

# %%
def _get_train_images_input_fn(file_pattern, image_size=(64, 64, 3), shuffle=False,
                 batch_size=32, num_epochs=None, buffer_size=4096):
    """get_input_fn exploits the `file_pattern` to create an input_fn that reads all the content
    of the specified pattern, creating an object dataset.
    
    Args:
        file_pattern: python string, the pattern of the file to read to generate the dataset
        image_size: the new size of the read images
        shuffle: True if the order of the elements in the generated dataset shold be randomized
        batch_size: the size of the batches
        num_epochs: the number of epochs to repeat the dataset before throwing an exeption; None is unlimited
        buffer_size: how many images read before starting to generate output
    Returns:
        input_fn: the generated input_fn that returns a correctly instantiated iterator
    """
    
    def _img_string_to_tensor(image_string):
        """Decode an image as read from a `tf.decode_raw`, scales it between 0-1 and resize the
        image as specified in the parent method.
        Args:
            image_string: the raw image tensor
        Returns:
            image_resize: image in [0,1] correctly resized
        """
        
        nonlocal image_size
        
        image_decoded = tf.image.decode_jpeg(image_string, channels=image_size[-1])
        # The conversion to float automatically scales the values in [0., 1.]
        image_decoded_as_float = tf.image.convert_image_dtype(image_decoded, dtype=tf.float32)
        image_decoded = (image_decoded_as_float - 0.5) * 2
        image_resized = tf.image.resize_images(image_decoded, size=image_size[:2])
        

        return image_resized

    def _path_to_img(path):
        """Given the path of an image, returns the pair (image, label)
        where image is the corretly resized image, and label is the label associated with it.
        Args:
            path: the path of the image to read
        Returns:
            (image_resized, label): the image, label pair associated the path
        """
        
        # Get the parent folder of this file to get its class
        # Associate the label 0 to dogs and 1 to cats
        label = tf.cond(
                    tf.equal(tf.string_split([path], delimiter='/').values[-2], "dogs"),
                    lambda: 0, lambda: 1)

        image_string = tf.read_file(path) # read image and process it
        image_resized = _img_string_to_tensor(image_string)

        return image_resized, label
    
    def _input_fn():
        """The input function that builds the `tf.data.Dataset` object and instantiate
        the iterator correctly ready to be use.
        Returns:
            the iterator associated to the built Dataset object.
        """
        
        # Use the static method `list_files` that builds a dataset of all
        # files matching this pattern.
        dataset_path = tf.data.Dataset.list_files(file_pattern)

        if shuffle:
            dataset_path = dataset_path.apply(tf.contrib.data.shuffle_and_repeat(buffer_size, num_epochs))
        else:
            dataset_path = dataset_path.repeat(num_epochs)

        # The map function maps the path to the pair (image, label)
        dataset = dataset_path.map(_path_to_img)
        dataset = dataset.apply(tf.contrib.data.batch_and_drop_remainder(batch_size))
        dataset = dataset.prefetch(buffer_size)
        
        iterator = dataset.make_one_shot_iterator()
        return iterator.get_next()

    return _input_fn()[0]

# %% [markdown]
# We define the `_get_train_input_fn()` which return a Python Callable that we instantiate and pass to `GANEstimator.train()` later on.

# %%
def _get_train_input_fn(file_pattern, batch_size, num_epochs, noise_dims=100, **kwargs):
    def train_input_fn():
        real_data = _get_train_images_input_fn(
                 file_pattern,
                 batch_size=batch_size, 
                 num_epochs=num_epochs)
        noise = tf.random_normal([batch_size, noise_dims], name="train_noise")
        real_data.set_shape((batch_size,) + tuple(real_data.shape[1:]))
        print(noise, real_data)
        return noise, real_data
    return train_input_fn

# %% [markdown]
# ### Hyperparameters

# %% [markdown]
# Personally I like to keep my hyperparameters in a **TOML** file, loading them before the train.
#
# Here we simply load them in a `Dict` and use `**` to unpack them.

# %%
def load_hyperparameters():
    hp = {
        "model_dir": "../logs/",
        "file_pattern": "../2. GANs in Tensorflow/dogscats/train/**/*.jpg",
        "batch_size": 128,
        "num_epochs":1000,
        "noise_dims": 100
    }
    return hp

# %% [markdown]
# ### Training

# %%
def dcgan():
    
    # Hyperparameters
    hyperparameters = load_hyperparameters()
    
    # Run Configuration (it has other arguments)
    run_config = tf.estimator.RunConfig(
        model_dir=hyperparameters.get("model_dir"), save_summary_steps=50, save_checkpoints_steps=500)
    
    # Instatiate the GANEstimator object
    gan_estimator = tfgan.estimator.GANEstimator(
        config=run_config,
        generator_fn=generator_fn,
        discriminator_fn=discriminator_fn,
        generator_loss_fn=tfgan.losses.modified_generator_loss,
        discriminator_loss_fn=tfgan.losses.modified_discriminator_loss,
        generator_optimizer=tf.train.AdamOptimizer(0.0002, 0.5),
        discriminator_optimizer=tf.train.AdamOptimizer(0.0002, 0.5),
        add_summaries=tfgan.estimator.SummaryType.IMAGES
    )
    
    # Instatiate the train_input_fn
    # The model will train until it exhausts the Dataset which is repeated EPOCH times
    train_input_fn = _get_train_input_fn(**hyperparameters)
    trained_model = gan_estimator.train(train_input_fn, max_steps=None)
    return trained_model

# %% [markdown]
# ### TensorBoard
#
# In order to track our training we need to launch a **TensorBoard** session pointing to the folder (`model_dir`) containing the logs generated by our training.
#
# ```bash
# tensorboard --logdir=PATH_TO_YOUR_MODEL_DIR
# ```

# %%
trained_model = dcgan()
# Out:
# INFO:tensorflow:Using config: {'_model_dir': '../logs/', '_tf_random_seed': None, '_save_summary_steps': 50, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f0e7b331be0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# Tensor("train_noise:0", shape=(128, 100), dtype=float32, device=/device:CPU:0) Tensor("IteratorGetNext:0", shape=(128, 64, 64, 3), dtype=float32, device=/device:CPU:0)
# INFO:tensorflow:Calling model_fn.
# Tensor("Generator/Tanh:0", shape=(128, 64, 64, 3), dtype=float32)
# INFO:tensorflow:Summary name Generator/dense/kernel:0 is illegal; using Generator/dense/kernel_0 instead.
# INFO:tensorflow:Summary name Generator/dense/bias:0 is illegal; using Generator/dense/bias_0 instead.
# INFO:tensorflow:Summary name Generator/batch_normalization/gamma:0 is illegal; using Generator/batch_normalization/gamma_0 instead.
# INFO:tensorflow:Summary name Generator/batch_normalization/beta:0 is illegal; using Generator/batch_normalization/beta_0 instead.
# INFO:tensorflow:Summary name Generator/conv2d/kernel:0 is illegal; using Generator/conv2d/kernel_0 instead.
# INFO:tensorflow:Summary name Generator/batch_normalization_1/gamma:0 is illegal; using Generator/batch_normalization_1/gamma_0 instead.
# INFO:tensorflow:Summary name Generator/batch_normalization_1/beta:0 is illegal; using Generator/batch_normalization_1/beta_0 instead.
# INFO:tensorflow:Summary name Generator/conv2d_1/kernel:0 is illegal; using Generator/conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name Generator/batch_normalization_2/gamma:0 is illegal; using Generator/batch_normalization_2/gamma_0 instead.
# INFO:tensorflow:Summary name Generator/batch_normalization_2/beta:0 is illegal; using Generator/batch_normalization_2/beta_0 instead.
# INFO:tensorflow:Summary name Generator/conv2d_2/kernel:0 is illegal; using Generator/conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name Generator/batch_normalization_3/gamma:0 is illegal; using Generator/batch_normalization_3/gamma_0 instead.
# INFO:tensorflow:Summary name Generator/batch_normalization_3/beta:0 is illegal; using Generator/batch_normalization_3/beta_0 instead.
# INFO:tensorflow:Summary name Generator/conv2d_3/kernel:0 is illegal; using Generator/conv2d_3/kernel_0 instead.
# INFO:tensorflow:Summary name Generator/conv2d_4/kernel:0 is illegal; using Generator/conv2d_4/kernel_0 instead.
# INFO:tensorflow:Summary name Discriminator/conv2d/kernel:0 is illegal; using Discriminator/conv2d/kernel_0 instead.
# INFO:tensorflow:Summary name Discriminator/batch_normalization/gamma:0 is illegal; using Discriminator/batch_normalization/gamma_0 instead.
# INFO:tensorflow:Summary name Discriminator/batch_normalization/beta:0 is illegal; using Discriminator/batch_normalization/beta_0 instead.
# INFO:tensorflow:Summary name Discriminator/conv2d_1/kernel:0 is illegal; using Discriminator/conv2d_1/kernel_0 instead.
# INFO:tensorflow:Summary name Discriminator/batch_normalization_1/gamma:0 is illegal; using Discriminator/batch_normalization_1/gamma_0 instead.
# INFO:tensorflow:Summary name Discriminator/batch_normalization_1/beta:0 is illegal; using Discriminator/batch_normalization_1/beta_0 instead.
# INFO:tensorflow:Summary name Discriminator/conv2d_2/kernel:0 is illegal; using Discriminator/conv2d_2/kernel_0 instead.
# INFO:tensorflow:Summary name Discriminator/batch_normalization_2/gamma:0 is illegal; using Discriminator/batch_normalization_2/gamma_0 instead.
# INFO:tensorflow:Summary name Discriminator/batch_normalization_2/beta:0 is illegal; using Discriminator/batch_normalization_2/beta_0 instead.
# INFO:tensorflow:Summary name Discriminator/conv2d_3/kernel:0 is illegal; using Discriminator/conv2d_3/kernel_0 instead.
# INFO:tensorflow:Summary name Discriminator/batch_normalization_3/gamma:0 is illegal; using Discriminator/batch_normalization_3/gamma_0 instead.
# INFO:tensorflow:Summary name Discriminator/batch_normalization_3/beta:0 is illegal; using Discriminator/batch_normalization_3/beta_0 instead.
# INFO:tensorflow:Summary name Discriminator/dense/kernel:0 is illegal; using Discriminator/dense/kernel_0 instead.
# INFO:tensorflow:Summary name Discriminator/dense/bias:0 is illegal; using Discriminator/dense/bias_0 instead.
# WARNING:tensorflow:update_ops in create_train_op does not contain all the  update_ops in GraphKeys.UPDATE_OPS
# WARNING:tensorflow:update_ops in create_train_op does not contain all the  update_ops in GraphKeys.UPDATE_OPS
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../logs/model.ckpt-31000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 31000 into ../logs/model.ckpt.
# INFO:tensorflow:loss = 5.157981, step = 31001
# INFO:tensorflow:global_step/sec: 1.7651
# INFO:tensorflow:loss = 6.828932, step = 31101 (56.639 sec)
# INFO:tensorflow:global_step/sec: 1.76911
# INFO:tensorflow:loss = 6.020489, step = 31201 (56.526 sec)
# INFO:tensorflow:global_step/sec: 1.76556
# INFO:tensorflow:loss = 7.647534, step = 31301 (56.639 sec)
# INFO:tensorflow:global_step/sec: 1.76545
# INFO:tensorflow:loss = 7.75236, step = 31401 (56.643 sec)
# INFO:tensorflow:Saving checkpoints for 31500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71205
# INFO:tensorflow:loss = 3.4447124, step = 31501 (58.409 sec)
# INFO:tensorflow:global_step/sec: 1.76371
# INFO:tensorflow:loss = 8.704723, step = 31601 (56.699 sec)
# INFO:tensorflow:global_step/sec: 1.76198
# INFO:tensorflow:loss = 6.3655033, step = 31701 (56.754 sec)
# INFO:tensorflow:global_step/sec: 1.76316
# INFO:tensorflow:loss = 6.626496, step = 31801 (56.716 sec)
# INFO:tensorflow:global_step/sec: 1.761
# INFO:tensorflow:loss = 5.570434, step = 31901 (56.786 sec)
# INFO:tensorflow:Saving checkpoints for 32000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.70466
# INFO:tensorflow:loss = 6.8690033, step = 32001 (58.663 sec)
# INFO:tensorflow:global_step/sec: 1.76054
# INFO:tensorflow:loss = 5.2305627, step = 32101 (56.801 sec)
# INFO:tensorflow:global_step/sec: 1.7609
# INFO:tensorflow:loss = 5.144003, step = 32201 (56.789 sec)
# INFO:tensorflow:global_step/sec: 1.76101
# INFO:tensorflow:loss = 5.6664414, step = 32301 (56.786 sec)
# INFO:tensorflow:global_step/sec: 1.75865
# INFO:tensorflow:loss = 5.9041033, step = 32401 (56.862 sec)
# INFO:tensorflow:Saving checkpoints for 32500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71099
# INFO:tensorflow:loss = 6.3639703, step = 32501 (58.445 sec)
# INFO:tensorflow:global_step/sec: 1.7626
# INFO:tensorflow:loss = 5.69061, step = 32601 (56.735 sec)
# INFO:tensorflow:global_step/sec: 1.76251
# INFO:tensorflow:loss = 6.414009, step = 32701 (56.737 sec)
# INFO:tensorflow:global_step/sec: 1.76173
# INFO:tensorflow:loss = 8.820028, step = 32801 (56.762 sec)
# INFO:tensorflow:global_step/sec: 1.76246
# INFO:tensorflow:loss = 5.707739, step = 32901 (56.739 sec)
# INFO:tensorflow:Saving checkpoints for 33000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.70876
# INFO:tensorflow:loss = 6.990354, step = 33001 (58.521 sec)
# INFO:tensorflow:global_step/sec: 1.76183
# INFO:tensorflow:loss = 5.7454004, step = 33101 (56.759 sec)
# INFO:tensorflow:global_step/sec: 1.76416
# INFO:tensorflow:loss = 6.039768, step = 33201 (56.685 sec)
# INFO:tensorflow:global_step/sec: 1.76446
# INFO:tensorflow:loss = 5.713437, step = 33301 (56.674 sec)
# INFO:tensorflow:global_step/sec: 1.76306
# INFO:tensorflow:loss = 5.557289, step = 33401 (56.720 sec)
# INFO:tensorflow:Saving checkpoints for 33500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.70818
# INFO:tensorflow:loss = 5.442759, step = 33501 (58.542 sec)
# INFO:tensorflow:global_step/sec: 1.76367
# INFO:tensorflow:loss = 5.433367, step = 33601 (56.700 sec)
# INFO:tensorflow:global_step/sec: 1.7638
# INFO:tensorflow:loss = 6.7992973, step = 33701 (56.696 sec)
# INFO:tensorflow:global_step/sec: 1.7648
# INFO:tensorflow:loss = 4.3675613, step = 33801 (56.663 sec)
# INFO:tensorflow:global_step/sec: 1.76412
# INFO:tensorflow:loss = 6.4518547, step = 33901 (56.686 sec)
# INFO:tensorflow:Saving checkpoints for 34000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72527
# INFO:tensorflow:loss = 10.858253, step = 34001 (57.962 sec)
# INFO:tensorflow:global_step/sec: 1.765
# INFO:tensorflow:loss = 6.28068, step = 34101 (56.657 sec)
# INFO:tensorflow:global_step/sec: 1.76348
# INFO:tensorflow:loss = 6.25112, step = 34201 (56.706 sec)
# INFO:tensorflow:global_step/sec: 1.76372
# INFO:tensorflow:loss = 7.2974973, step = 34301 (56.698 sec)
# INFO:tensorflow:global_step/sec: 1.76371
# INFO:tensorflow:loss = 4.905837, step = 34401 (56.698 sec)
# INFO:tensorflow:Saving checkpoints for 34500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72012
# INFO:tensorflow:loss = 6.519368, step = 34501 (58.136 sec)
# INFO:tensorflow:global_step/sec: 1.7626
# INFO:tensorflow:loss = 4.2129803, step = 34601 (56.734 sec)
# INFO:tensorflow:global_step/sec: 1.76329
# INFO:tensorflow:loss = 6.080983, step = 34701 (56.712 sec)
# INFO:tensorflow:global_step/sec: 1.7636
# INFO:tensorflow:loss = 7.5746703, step = 34801 (56.702 sec)
# INFO:tensorflow:global_step/sec: 1.76347
# INFO:tensorflow:loss = 7.3876987, step = 34901 (56.707 sec)
# INFO:tensorflow:Saving checkpoints for 35000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72197
# INFO:tensorflow:loss = 9.611346, step = 35001 (58.073 sec)
# INFO:tensorflow:global_step/sec: 1.76469
# INFO:tensorflow:loss = 5.7200594, step = 35101 (56.668 sec)
# INFO:tensorflow:global_step/sec: 1.76452
# INFO:tensorflow:loss = 7.5637617, step = 35201 (56.673 sec)
# INFO:tensorflow:global_step/sec: 1.76474
# INFO:tensorflow:loss = 6.1114616, step = 35301 (56.665 sec)
# INFO:tensorflow:global_step/sec: 1.76409
# INFO:tensorflow:loss = 6.094907, step = 35401 (56.686 sec)
# INFO:tensorflow:Saving checkpoints for 35500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72512
# INFO:tensorflow:loss = 6.7577367, step = 35501 (57.967 sec)
# INFO:tensorflow:global_step/sec: 1.76374
# INFO:tensorflow:loss = 7.84905, step = 35601 (56.698 sec)
# INFO:tensorflow:global_step/sec: 1.76362
# INFO:tensorflow:loss = 6.682164, step = 35701 (56.702 sec)
# INFO:tensorflow:global_step/sec: 1.76477
# INFO:tensorflow:loss = 6.453903, step = 35801 (56.665 sec)
# INFO:tensorflow:global_step/sec: 1.75125
# INFO:tensorflow:loss = 4.399605, step = 35901 (57.115 sec)
# INFO:tensorflow:Saving checkpoints for 36000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72122
# INFO:tensorflow:loss = 7.0016546, step = 36001 (58.085 sec)
# INFO:tensorflow:global_step/sec: 1.76228
# INFO:tensorflow:loss = 5.7955875, step = 36101 (56.746 sec)
# INFO:tensorflow:global_step/sec: 1.76409
# INFO:tensorflow:loss = 6.543535, step = 36201 (56.685 sec)
# INFO:tensorflow:global_step/sec: 1.76499
# INFO:tensorflow:loss = 7.0055633, step = 36301 (56.657 sec)
# INFO:tensorflow:global_step/sec: 1.76435
# INFO:tensorflow:loss = 5.8104973, step = 36401 (56.678 sec)
# INFO:tensorflow:Saving checkpoints for 36500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72017
# INFO:tensorflow:loss = 6.0455017, step = 36501 (58.133 sec)
# INFO:tensorflow:global_step/sec: 1.7661
# INFO:tensorflow:loss = 6.8925858, step = 36601 (56.622 sec)
# INFO:tensorflow:global_step/sec: 1.76493
# INFO:tensorflow:loss = 7.127204, step = 36701 (56.660 sec)
# INFO:tensorflow:global_step/sec: 1.76514
# INFO:tensorflow:loss = 5.392818, step = 36801 (56.653 sec)
# INFO:tensorflow:global_step/sec: 1.76522
# INFO:tensorflow:loss = 6.085166, step = 36901 (56.650 sec)
# INFO:tensorflow:Saving checkpoints for 37000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72167
# INFO:tensorflow:loss = 4.0305514, step = 37001 (58.083 sec)
# INFO:tensorflow:global_step/sec: 1.76441
# INFO:tensorflow:loss = 5.6874433, step = 37101 (56.676 sec)
# INFO:tensorflow:global_step/sec: 1.76483
# INFO:tensorflow:loss = 7.405565, step = 37201 (56.663 sec)
# INFO:tensorflow:global_step/sec: 1.76381
# INFO:tensorflow:loss = 5.959334, step = 37301 (56.695 sec)
# INFO:tensorflow:global_step/sec: 1.76317
# INFO:tensorflow:loss = 4.379068, step = 37401 (56.716 sec)
# INFO:tensorflow:Saving checkpoints for 37500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72517
# INFO:tensorflow:loss = 5.8524604, step = 37501 (57.965 sec)
# INFO:tensorflow:global_step/sec: 1.76364
# INFO:tensorflow:loss = 3.1111326, step = 37601 (56.701 sec)
# INFO:tensorflow:global_step/sec: 1.76365
# INFO:tensorflow:loss = 4.8392344, step = 37701 (56.700 sec)
# INFO:tensorflow:global_step/sec: 1.76461
# INFO:tensorflow:loss = 6.2290483, step = 37801 (56.670 sec)
# INFO:tensorflow:global_step/sec: 1.76262
# INFO:tensorflow:loss = 4.592672, step = 37901 (56.734 sec)
# INFO:tensorflow:Saving checkpoints for 38000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72288
# INFO:tensorflow:loss = 9.582094, step = 38001 (58.042 sec)
# INFO:tensorflow:global_step/sec: 1.7637
# INFO:tensorflow:loss = 4.5980387, step = 38101 (56.699 sec)
# INFO:tensorflow:global_step/sec: 1.76414
# INFO:tensorflow:loss = 6.277553, step = 38201 (56.684 sec)
# INFO:tensorflow:global_step/sec: 1.76332
# INFO:tensorflow:loss = 7.3212547, step = 38301 (56.711 sec)
# INFO:tensorflow:global_step/sec: 1.75195
# INFO:tensorflow:loss = 6.4799066, step = 38401 (57.079 sec)
# INFO:tensorflow:Saving checkpoints for 38500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71865
# INFO:tensorflow:loss = 6.901095, step = 38501 (58.185 sec)
# INFO:tensorflow:global_step/sec: 1.76404
# INFO:tensorflow:loss = 5.964098, step = 38601 (56.688 sec)
# INFO:tensorflow:global_step/sec: 1.76406
# INFO:tensorflow:loss = 6.825963, step = 38701 (56.687 sec)
# INFO:tensorflow:global_step/sec: 1.76416
# INFO:tensorflow:loss = 6.666295, step = 38801 (56.684 sec)
# INFO:tensorflow:global_step/sec: 1.76376
# INFO:tensorflow:loss = 5.9263477, step = 38901 (56.697 sec)
# INFO:tensorflow:Saving checkpoints for 39000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72396
# INFO:tensorflow:loss = 4.280479, step = 39001 (58.006 sec)
# INFO:tensorflow:global_step/sec: 1.76441
# INFO:tensorflow:loss = 6.9447155, step = 39101 (56.676 sec)
# INFO:tensorflow:global_step/sec: 1.76405
# INFO:tensorflow:loss = 4.293243, step = 39201 (56.688 sec)
# INFO:tensorflow:global_step/sec: 1.76397
# INFO:tensorflow:loss = 5.5917387, step = 39301 (56.691 sec)
# INFO:tensorflow:global_step/sec: 1.76416
# INFO:tensorflow:loss = 8.828355, step = 39401 (56.684 sec)
# INFO:tensorflow:Saving checkpoints for 39500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71987
# INFO:tensorflow:loss = 6.237158, step = 39501 (58.144 sec)
# INFO:tensorflow:global_step/sec: 1.76356
# INFO:tensorflow:loss = 5.2160635, step = 39601 (56.704 sec)
# INFO:tensorflow:global_step/sec: 1.7635
# INFO:tensorflow:loss = 5.807359, step = 39701 (56.705 sec)
# INFO:tensorflow:global_step/sec: 1.7628
# INFO:tensorflow:loss = 5.0468183, step = 39801 (56.728 sec)
# INFO:tensorflow:global_step/sec: 1.76386
# INFO:tensorflow:loss = 6.1966534, step = 39901 (56.694 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71965
# INFO:tensorflow:loss = 6.498234, step = 40001 (58.151 sec)
# INFO:tensorflow:global_step/sec: 1.76366
# INFO:tensorflow:loss = 6.666383, step = 40101 (56.701 sec)
# INFO:tensorflow:global_step/sec: 1.76301
# INFO:tensorflow:loss = 7.7187634, step = 40201 (56.721 sec)
# INFO:tensorflow:global_step/sec: 1.76303
# INFO:tensorflow:loss = 7.46049, step = 40301 (56.720 sec)
# INFO:tensorflow:global_step/sec: 1.76355
# INFO:tensorflow:loss = 5.873543, step = 40401 (56.704 sec)
# INFO:tensorflow:Saving checkpoints for 40500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72352
# INFO:tensorflow:loss = 7.5832834, step = 40501 (58.021 sec)
# INFO:tensorflow:global_step/sec: 1.76388
# INFO:tensorflow:loss = 7.189584, step = 40601 (56.693 sec)
# INFO:tensorflow:global_step/sec: 1.76314
# INFO:tensorflow:loss = 6.9292564, step = 40701 (56.717 sec)
# INFO:tensorflow:global_step/sec: 1.75288
# INFO:tensorflow:loss = 13.677985, step = 40801 (57.063 sec)
# INFO:tensorflow:global_step/sec: 1.76355
# INFO:tensorflow:loss = 3.620974, step = 40901 (56.690 sec)
# INFO:tensorflow:Saving checkpoints for 41000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71935
# INFO:tensorflow:loss = 6.1687727, step = 41001 (58.161 sec)
# INFO:tensorflow:global_step/sec: 1.76439
# INFO:tensorflow:loss = 7.374987, step = 41101 (56.677 sec)
# INFO:tensorflow:global_step/sec: 1.76357
# INFO:tensorflow:loss = 6.8004813, step = 41201 (56.703 sec)
# INFO:tensorflow:global_step/sec: 1.7628
# INFO:tensorflow:loss = 6.4818535, step = 41301 (56.728 sec)
# INFO:tensorflow:global_step/sec: 1.76341
# INFO:tensorflow:loss = 7.7191343, step = 41401 (56.709 sec)
# INFO:tensorflow:Saving checkpoints for 41500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72063
# INFO:tensorflow:loss = 5.2683682, step = 41501 (58.118 sec)
# INFO:tensorflow:global_step/sec: 1.76397
# INFO:tensorflow:loss = 7.5246572, step = 41601 (56.690 sec)
# INFO:tensorflow:global_step/sec: 1.76328
# INFO:tensorflow:loss = 6.5528636, step = 41701 (56.713 sec)
# INFO:tensorflow:global_step/sec: 1.76141
# INFO:tensorflow:loss = 5.471864, step = 41801 (56.773 sec)
# INFO:tensorflow:global_step/sec: 1.76214
# INFO:tensorflow:loss = 5.937796, step = 41901 (56.749 sec)
# INFO:tensorflow:Saving checkpoints for 42000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72507
# INFO:tensorflow:loss = 5.1321173, step = 42001 (57.969 sec)
# INFO:tensorflow:global_step/sec: 1.76315
# INFO:tensorflow:loss = 6.212233, step = 42101 (56.716 sec)
# INFO:tensorflow:global_step/sec: 1.7637
# INFO:tensorflow:loss = 6.3072004, step = 42201 (56.699 sec)
# INFO:tensorflow:global_step/sec: 1.76353
# INFO:tensorflow:loss = 6.5442333, step = 42301 (56.704 sec)
# INFO:tensorflow:global_step/sec: 1.76383
# INFO:tensorflow:loss = 8.397507, step = 42401 (56.695 sec)
# INFO:tensorflow:Saving checkpoints for 42500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72332
# INFO:tensorflow:loss = 6.8485355, step = 42501 (58.027 sec)
# INFO:tensorflow:global_step/sec: 1.76224
# INFO:tensorflow:loss = 6.2130246, step = 42601 (56.746 sec)
# INFO:tensorflow:global_step/sec: 1.76307
# INFO:tensorflow:loss = 7.614183, step = 42701 (56.719 sec)
# INFO:tensorflow:global_step/sec: 1.76289
# INFO:tensorflow:loss = 7.2392683, step = 42801 (56.725 sec)
# INFO:tensorflow:global_step/sec: 1.7633
# INFO:tensorflow:loss = 7.7899494, step = 42901 (56.712 sec)
# INFO:tensorflow:Saving checkpoints for 43000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71992
# INFO:tensorflow:loss = 6.254429, step = 43001 (58.142 sec)
# INFO:tensorflow:global_step/sec: 1.76345
# INFO:tensorflow:loss = 7.4175334, step = 43101 (56.707 sec)
# INFO:tensorflow:global_step/sec: 1.76343
# INFO:tensorflow:loss = 6.4968944, step = 43201 (56.708 sec)
# INFO:tensorflow:global_step/sec: 1.75323
# INFO:tensorflow:loss = 3.9008656, step = 43301 (57.038 sec)
# INFO:tensorflow:global_step/sec: 1.76395
# INFO:tensorflow:loss = 6.8492227, step = 43401 (56.691 sec)
# INFO:tensorflow:Saving checkpoints for 43500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72226
# INFO:tensorflow:loss = 6.367875, step = 43501 (58.063 sec)
# INFO:tensorflow:global_step/sec: 1.76443
# INFO:tensorflow:loss = 6.387255, step = 43601 (56.676 sec)
# INFO:tensorflow:global_step/sec: 1.76366
# INFO:tensorflow:loss = 6.456077, step = 43701 (56.701 sec)
# INFO:tensorflow:global_step/sec: 1.76466
# INFO:tensorflow:loss = 7.5854387, step = 43801 (56.668 sec)
# INFO:tensorflow:global_step/sec: 1.76267
# INFO:tensorflow:loss = 3.9852412, step = 43901 (56.732 sec)
# INFO:tensorflow:Saving checkpoints for 44000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72345
# INFO:tensorflow:loss = 8.002531, step = 44001 (58.023 sec)
# INFO:tensorflow:global_step/sec: 1.76434
# INFO:tensorflow:loss = 6.640115, step = 44101 (56.679 sec)
# INFO:tensorflow:global_step/sec: 1.76389
# INFO:tensorflow:loss = 6.509479, step = 44201 (56.693 sec)
# INFO:tensorflow:global_step/sec: 1.76373
# INFO:tensorflow:loss = 6.6745906, step = 44301 (56.698 sec)
# INFO:tensorflow:global_step/sec: 1.76386
# INFO:tensorflow:loss = 6.5006986, step = 44401 (56.694 sec)
# INFO:tensorflow:Saving checkpoints for 44500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72192
# INFO:tensorflow:loss = 7.012354, step = 44501 (58.075 sec)
# INFO:tensorflow:global_step/sec: 1.76397
# INFO:tensorflow:loss = 6.1733756, step = 44601 (56.690 sec)
# INFO:tensorflow:global_step/sec: 1.76448
# INFO:tensorflow:loss = 7.0710626, step = 44701 (56.674 sec)
# INFO:tensorflow:global_step/sec: 1.76426
# INFO:tensorflow:loss = 8.520772, step = 44801 (56.681 sec)
# INFO:tensorflow:global_step/sec: 1.76193
# INFO:tensorflow:loss = 6.3677216, step = 44901 (56.756 sec)
# INFO:tensorflow:Saving checkpoints for 45000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72136
# INFO:tensorflow:loss = 7.4174047, step = 45001 (58.094 sec)
# INFO:tensorflow:global_step/sec: 1.76274
# INFO:tensorflow:loss = 5.443684, step = 45101 (56.730 sec)
# INFO:tensorflow:global_step/sec: 1.76291
# INFO:tensorflow:loss = 6.1868706, step = 45201 (56.724 sec)
# INFO:tensorflow:global_step/sec: 1.76396
# INFO:tensorflow:loss = 4.639564, step = 45301 (56.690 sec)
# INFO:tensorflow:global_step/sec: 1.76304
# INFO:tensorflow:loss = 6.903273, step = 45401 (56.720 sec)
# INFO:tensorflow:Saving checkpoints for 45500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72142
# INFO:tensorflow:loss = 7.515713, step = 45501 (58.092 sec)
# INFO:tensorflow:global_step/sec: 1.76399
# INFO:tensorflow:loss = 8.396705, step = 45601 (56.690 sec)
# INFO:tensorflow:global_step/sec: 1.75003
# INFO:tensorflow:loss = 5.5338454, step = 45701 (57.157 sec)
# INFO:tensorflow:global_step/sec: 1.76307
# INFO:tensorflow:loss = 5.832625, step = 45801 (56.705 sec)
# INFO:tensorflow:global_step/sec: 1.76204
# INFO:tensorflow:loss = 7.3095675, step = 45901 (56.753 sec)
# INFO:tensorflow:Saving checkpoints for 46000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72475
# INFO:tensorflow:loss = 7.242199, step = 46001 (57.979 sec)
# INFO:tensorflow:global_step/sec: 1.76265
# INFO:tensorflow:loss = 7.4749637, step = 46101 (56.733 sec)
# INFO:tensorflow:global_step/sec: 1.76275
# INFO:tensorflow:loss = 6.211016, step = 46201 (56.729 sec)
# INFO:tensorflow:global_step/sec: 1.76355
# INFO:tensorflow:loss = 6.6437893, step = 46301 (56.704 sec)
# INFO:tensorflow:global_step/sec: 1.76346
# INFO:tensorflow:loss = 6.9735537, step = 46401 (56.707 sec)
# INFO:tensorflow:Saving checkpoints for 46500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71954
# INFO:tensorflow:loss = 5.823208, step = 46501 (58.155 sec)
# INFO:tensorflow:global_step/sec: 1.76339
# INFO:tensorflow:loss = 6.1383443, step = 46601 (56.709 sec)
# INFO:tensorflow:global_step/sec: 1.76378
# INFO:tensorflow:loss = 6.607573, step = 46701 (56.697 sec)
# INFO:tensorflow:global_step/sec: 1.76177
# INFO:tensorflow:loss = 7.128957, step = 46801 (56.761 sec)
# INFO:tensorflow:global_step/sec: 1.76405
# INFO:tensorflow:loss = 5.698142, step = 46901 (56.688 sec)
# INFO:tensorflow:Saving checkpoints for 47000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72058
# INFO:tensorflow:loss = 7.2892165, step = 47001 (58.120 sec)
# INFO:tensorflow:global_step/sec: 1.76354
# INFO:tensorflow:loss = 5.7723145, step = 47101 (56.704 sec)
# INFO:tensorflow:global_step/sec: 1.76382
# INFO:tensorflow:loss = 7.049006, step = 47201 (56.695 sec)
# INFO:tensorflow:global_step/sec: 1.76461
# INFO:tensorflow:loss = 7.506782, step = 47301 (56.670 sec)
# INFO:tensorflow:global_step/sec: 1.76249
# INFO:tensorflow:loss = 6.529416, step = 47401 (56.738 sec)
# INFO:tensorflow:Saving checkpoints for 47500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72391
# INFO:tensorflow:loss = 6.5910735, step = 47501 (58.008 sec)
# INFO:tensorflow:global_step/sec: 1.76449
# INFO:tensorflow:loss = 7.6038227, step = 47601 (56.674 sec)
# INFO:tensorflow:global_step/sec: 1.76221
# INFO:tensorflow:loss = 5.5080824, step = 47701 (56.747 sec)
# INFO:tensorflow:global_step/sec: 1.76181
# INFO:tensorflow:loss = 5.6206527, step = 47801 (56.760 sec)
# INFO:tensorflow:global_step/sec: 1.76386
# INFO:tensorflow:loss = 5.7264466, step = 47901 (56.694 sec)
# INFO:tensorflow:Saving checkpoints for 48000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72341
# INFO:tensorflow:loss = 6.8356805, step = 48001 (58.024 sec)
# INFO:tensorflow:global_step/sec: 1.76425
# INFO:tensorflow:loss = 5.4918003, step = 48101 (56.681 sec)
# INFO:tensorflow:global_step/sec: 1.7499
# INFO:tensorflow:loss = 8.116854, step = 48201 (57.146 sec)
# INFO:tensorflow:global_step/sec: 1.76271
# INFO:tensorflow:loss = 5.160519, step = 48301 (56.731 sec)
# INFO:tensorflow:global_step/sec: 1.76396
# INFO:tensorflow:loss = 5.94569, step = 48401 (56.691 sec)
# INFO:tensorflow:Saving checkpoints for 48500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71883
# INFO:tensorflow:loss = 7.1108923, step = 48501 (58.179 sec)
# INFO:tensorflow:global_step/sec: 1.76277
# INFO:tensorflow:loss = 6.105492, step = 48601 (56.729 sec)
# INFO:tensorflow:global_step/sec: 1.76317
# INFO:tensorflow:loss = 7.539501, step = 48701 (56.716 sec)
# INFO:tensorflow:global_step/sec: 1.76355
# INFO:tensorflow:loss = 7.745761, step = 48801 (56.704 sec)
# INFO:tensorflow:global_step/sec: 1.76385
# INFO:tensorflow:loss = 7.1053495, step = 48901 (56.694 sec)
# INFO:tensorflow:Saving checkpoints for 49000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72398
# INFO:tensorflow:loss = 6.9362965, step = 49001 (58.005 sec)
# INFO:tensorflow:global_step/sec: 1.76185
# INFO:tensorflow:loss = 14.891137, step = 49101 (56.759 sec)
# INFO:tensorflow:global_step/sec: 1.7633
# INFO:tensorflow:loss = 7.357452, step = 49201 (56.712 sec)
# INFO:tensorflow:global_step/sec: 1.76258
# INFO:tensorflow:loss = 7.4554286, step = 49301 (56.735 sec)
# INFO:tensorflow:global_step/sec: 1.7625
# INFO:tensorflow:loss = 7.7146187, step = 49401 (56.738 sec)
# INFO:tensorflow:Saving checkpoints for 49500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72137
# INFO:tensorflow:loss = 6.891047, step = 49501 (58.093 sec)
# INFO:tensorflow:global_step/sec: 1.76272
# INFO:tensorflow:loss = 7.0805645, step = 49601 (56.731 sec)
# INFO:tensorflow:global_step/sec: 1.76325
# INFO:tensorflow:loss = 7.255398, step = 49701 (56.714 sec)
# INFO:tensorflow:global_step/sec: 1.76208
# INFO:tensorflow:loss = 6.963095, step = 49801 (56.751 sec)
# INFO:tensorflow:global_step/sec: 1.7635
# INFO:tensorflow:loss = 5.538699, step = 49901 (56.705 sec)
# INFO:tensorflow:Saving checkpoints for 50000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.7222
# INFO:tensorflow:loss = 5.6057115, step = 50001 (58.065 sec)
# INFO:tensorflow:global_step/sec: 1.76304
# INFO:tensorflow:loss = 5.211167, step = 50101 (56.720 sec)
# INFO:tensorflow:global_step/sec: 1.76323
# INFO:tensorflow:loss = 6.65103, step = 50201 (56.714 sec)
# INFO:tensorflow:global_step/sec: 1.7632
# INFO:tensorflow:loss = 6.992386, step = 50301 (56.715 sec)
# INFO:tensorflow:global_step/sec: 1.76182
# INFO:tensorflow:loss = 6.979085, step = 50401 (56.759 sec)
# INFO:tensorflow:Saving checkpoints for 50500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72095
# INFO:tensorflow:loss = 7.5700636, step = 50501 (58.107 sec)
# INFO:tensorflow:global_step/sec: 1.75202
# INFO:tensorflow:loss = 7.329545, step = 50601 (57.090 sec)
# INFO:tensorflow:global_step/sec: 1.76261
# INFO:tensorflow:loss = 4.89971, step = 50701 (56.721 sec)
# INFO:tensorflow:global_step/sec: 1.76428
# INFO:tensorflow:loss = 6.3124065, step = 50801 (56.680 sec)
# INFO:tensorflow:global_step/sec: 1.76419
# INFO:tensorflow:loss = 6.1320295, step = 50901 (56.683 sec)
# INFO:tensorflow:Saving checkpoints for 51000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.7208
# INFO:tensorflow:loss = 7.92556, step = 51001 (58.113 sec)
# INFO:tensorflow:global_step/sec: 1.76391
# INFO:tensorflow:loss = 12.876017, step = 51101 (56.693 sec)
# INFO:tensorflow:global_step/sec: 1.76418
# INFO:tensorflow:loss = 6.562066, step = 51201 (56.683 sec)
# INFO:tensorflow:global_step/sec: 1.76463
# INFO:tensorflow:loss = 6.9972754, step = 51301 (56.669 sec)
# INFO:tensorflow:global_step/sec: 1.76221
# INFO:tensorflow:loss = 5.887077, step = 51401 (56.747 sec)
# INFO:tensorflow:Saving checkpoints for 51500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72496
# INFO:tensorflow:loss = 14.508533, step = 51501 (57.972 sec)
# INFO:tensorflow:global_step/sec: 1.76329
# INFO:tensorflow:loss = 6.516595, step = 51601 (56.712 sec)
# INFO:tensorflow:global_step/sec: 1.76232
# INFO:tensorflow:loss = 7.2693815, step = 51701 (56.743 sec)
# INFO:tensorflow:global_step/sec: 1.76397
# INFO:tensorflow:loss = 6.3305855, step = 51801 (56.690 sec)
# INFO:tensorflow:global_step/sec: 1.7633
# INFO:tensorflow:loss = 7.04784, step = 51901 (56.712 sec)
# INFO:tensorflow:Saving checkpoints for 52000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72287
# INFO:tensorflow:loss = 7.6257114, step = 52001 (58.042 sec)
# INFO:tensorflow:global_step/sec: 1.76377
# INFO:tensorflow:loss = 6.5995073, step = 52101 (56.697 sec)
# INFO:tensorflow:global_step/sec: 1.76323
# INFO:tensorflow:loss = 8.148257, step = 52201 (56.714 sec)
# INFO:tensorflow:global_step/sec: 1.76448
# INFO:tensorflow:loss = 6.7429404, step = 52301 (56.674 sec)
# INFO:tensorflow:global_step/sec: 1.76384
# INFO:tensorflow:loss = 8.141324, step = 52401 (56.695 sec)
# INFO:tensorflow:Saving checkpoints for 52500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71948
# INFO:tensorflow:loss = 7.9253216, step = 52501 (58.157 sec)
# INFO:tensorflow:global_step/sec: 1.76421
# INFO:tensorflow:loss = 6.934967, step = 52601 (56.683 sec)
# INFO:tensorflow:global_step/sec: 1.76468
# INFO:tensorflow:loss = 6.7523623, step = 52701 (56.667 sec)
# INFO:tensorflow:global_step/sec: 1.76418
# INFO:tensorflow:loss = 8.822882, step = 52801 (56.683 sec)
# INFO:tensorflow:global_step/sec: 1.76448
# INFO:tensorflow:loss = 6.5398345, step = 52901 (56.674 sec)
# INFO:tensorflow:Saving checkpoints for 53000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72091
# INFO:tensorflow:loss = 6.475323, step = 53001 (58.108 sec)
# INFO:tensorflow:global_step/sec: 1.7527
# INFO:tensorflow:loss = 7.031607, step = 53101 (57.055 sec)
# INFO:tensorflow:global_step/sec: 1.76207
# INFO:tensorflow:loss = 6.2338643, step = 53201 (56.751 sec)
# INFO:tensorflow:global_step/sec: 1.76483
# INFO:tensorflow:loss = 7.530015, step = 53301 (56.663 sec)
# INFO:tensorflow:global_step/sec: 1.7631
# INFO:tensorflow:loss = 4.482033, step = 53401 (56.718 sec)
# INFO:tensorflow:Saving checkpoints for 53500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72335
# INFO:tensorflow:loss = 7.924967, step = 53501 (58.026 sec)
# INFO:tensorflow:global_step/sec: 1.76445
# INFO:tensorflow:loss = 6.7883143, step = 53601 (56.675 sec)
# INFO:tensorflow:global_step/sec: 1.76389
# INFO:tensorflow:loss = 6.89011, step = 53701 (56.693 sec)
# INFO:tensorflow:global_step/sec: 1.76352
# INFO:tensorflow:loss = 7.836812, step = 53801 (56.705 sec)
# INFO:tensorflow:global_step/sec: 1.76571
# INFO:tensorflow:loss = 6.7438226, step = 53901 (56.634 sec)
# INFO:tensorflow:Saving checkpoints for 54000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71967
# INFO:tensorflow:loss = 6.07094, step = 54001 (58.151 sec)
# INFO:tensorflow:global_step/sec: 1.76501
# INFO:tensorflow:loss = 7.69845, step = 54101 (56.656 sec)
# INFO:tensorflow:global_step/sec: 1.76392
# INFO:tensorflow:loss = 6.8267283, step = 54201 (56.692 sec)
# INFO:tensorflow:global_step/sec: 1.76411
# INFO:tensorflow:loss = 6.5692496, step = 54301 (56.686 sec)
# INFO:tensorflow:global_step/sec: 1.76304
# INFO:tensorflow:loss = 7.7618318, step = 54401 (56.720 sec)
# INFO:tensorflow:Saving checkpoints for 54500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71877
# INFO:tensorflow:loss = 7.347197, step = 54501 (58.181 sec)
# INFO:tensorflow:global_step/sec: 1.76411
# INFO:tensorflow:loss = 6.0327535, step = 54601 (56.686 sec)
# INFO:tensorflow:global_step/sec: 1.76266
# INFO:tensorflow:loss = 6.800518, step = 54701 (56.733 sec)
# INFO:tensorflow:global_step/sec: 1.7637
# INFO:tensorflow:loss = 6.3270373, step = 54801 (56.699 sec)
# INFO:tensorflow:global_step/sec: 1.76348
# INFO:tensorflow:loss = 7.056262, step = 54901 (56.706 sec)
# INFO:tensorflow:Saving checkpoints for 55000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72034
# INFO:tensorflow:loss = 8.16275, step = 55001 (58.128 sec)
# INFO:tensorflow:global_step/sec: 1.76402
# INFO:tensorflow:loss = 7.553857, step = 55101 (56.689 sec)
# INFO:tensorflow:global_step/sec: 1.76395
# INFO:tensorflow:loss = 6.3373303, step = 55201 (56.690 sec)
# INFO:tensorflow:global_step/sec: 1.76406
# INFO:tensorflow:loss = 7.321006, step = 55301 (56.687 sec)
# INFO:tensorflow:global_step/sec: 1.76341
# INFO:tensorflow:loss = 6.2219424, step = 55401 (56.708 sec)
# INFO:tensorflow:Saving checkpoints for 55500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71329
# INFO:tensorflow:loss = 7.413375, step = 55501 (58.381 sec)
# INFO:tensorflow:global_step/sec: 1.76204
# INFO:tensorflow:loss = 6.752772, step = 55601 (56.739 sec)
# INFO:tensorflow:global_step/sec: 1.76308
# INFO:tensorflow:loss = 6.829056, step = 55701 (56.718 sec)
# INFO:tensorflow:global_step/sec: 1.76437
# INFO:tensorflow:loss = 7.183496, step = 55801 (56.678 sec)
# INFO:tensorflow:global_step/sec: 1.76368
# INFO:tensorflow:loss = 5.5365353, step = 55901 (56.700 sec)
# INFO:tensorflow:Saving checkpoints for 56000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72011
# INFO:tensorflow:loss = 7.562919, step = 56001 (58.135 sec)
# INFO:tensorflow:global_step/sec: 1.7649
# INFO:tensorflow:loss = 5.9322166, step = 56101 (56.661 sec)
# INFO:tensorflow:global_step/sec: 1.76375
# INFO:tensorflow:loss = 8.262776, step = 56201 (56.697 sec)
# INFO:tensorflow:global_step/sec: 1.76353
# INFO:tensorflow:loss = 6.2420926, step = 56301 (56.704 sec)
# INFO:tensorflow:global_step/sec: 1.7638
# INFO:tensorflow:loss = 6.4799175, step = 56401 (56.696 sec)
# INFO:tensorflow:Saving checkpoints for 56500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72118
# INFO:tensorflow:loss = 7.4520884, step = 56501 (58.099 sec)
# INFO:tensorflow:global_step/sec: 1.76429
# INFO:tensorflow:loss = 8.267626, step = 56601 (56.680 sec)
# INFO:tensorflow:global_step/sec: 1.76265
# INFO:tensorflow:loss = 7.023814, step = 56701 (56.733 sec)
# INFO:tensorflow:global_step/sec: 1.76256
# INFO:tensorflow:loss = 7.2528944, step = 56801 (56.736 sec)
# INFO:tensorflow:global_step/sec: 1.76347
# INFO:tensorflow:loss = 7.6648545, step = 56901 (56.707 sec)
# INFO:tensorflow:Saving checkpoints for 57000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72409
# INFO:tensorflow:loss = 6.6203237, step = 57001 (58.002 sec)
# INFO:tensorflow:global_step/sec: 1.76478
# INFO:tensorflow:loss = 6.94283, step = 57101 (56.664 sec)
# INFO:tensorflow:global_step/sec: 1.76254
# INFO:tensorflow:loss = 5.9522815, step = 57201 (56.736 sec)
# INFO:tensorflow:global_step/sec: 1.7612
# INFO:tensorflow:loss = 7.9639554, step = 57301 (56.779 sec)
# INFO:tensorflow:global_step/sec: 1.76377
# INFO:tensorflow:loss = 8.099914, step = 57401 (56.697 sec)
# INFO:tensorflow:Saving checkpoints for 57500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72392
# INFO:tensorflow:loss = 7.700861, step = 57501 (58.007 sec)
# INFO:tensorflow:global_step/sec: 1.76381
# INFO:tensorflow:loss = 7.343155, step = 57601 (56.695 sec)
# INFO:tensorflow:global_step/sec: 1.76257
# INFO:tensorflow:loss = 8.46584, step = 57701 (56.735 sec)
# INFO:tensorflow:global_step/sec: 1.76347
# INFO:tensorflow:loss = 6.2135434, step = 57801 (56.706 sec)
# INFO:tensorflow:global_step/sec: 1.76397
# INFO:tensorflow:loss = 6.0756016, step = 57901 (56.690 sec)
# INFO:tensorflow:Saving checkpoints for 58000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.70801
# INFO:tensorflow:loss = 7.763259, step = 58001 (58.548 sec)
# INFO:tensorflow:global_step/sec: 1.7649
# INFO:tensorflow:loss = 5.8821397, step = 58101 (56.660 sec)
# INFO:tensorflow:global_step/sec: 1.76352
# INFO:tensorflow:loss = 5.7200184, step = 58201 (56.705 sec)
# INFO:tensorflow:global_step/sec: 1.76391
# INFO:tensorflow:loss = 7.179782, step = 58301 (56.692 sec)
# INFO:tensorflow:global_step/sec: 1.76375
# INFO:tensorflow:loss = 8.025618, step = 58401 (56.698 sec)
# INFO:tensorflow:Saving checkpoints for 58500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72149
# INFO:tensorflow:loss = 6.773908, step = 58501 (58.089 sec)
# INFO:tensorflow:global_step/sec: 1.76514
# INFO:tensorflow:loss = 6.099367, step = 58601 (56.653 sec)
# INFO:tensorflow:global_step/sec: 1.76315
# INFO:tensorflow:loss = 6.540289, step = 58701 (56.717 sec)
# INFO:tensorflow:global_step/sec: 1.76392
# INFO:tensorflow:loss = 8.119874, step = 58801 (56.692 sec)
# INFO:tensorflow:global_step/sec: 1.76343
# INFO:tensorflow:loss = 7.336808, step = 58901 (56.707 sec)
# INFO:tensorflow:Saving checkpoints for 59000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72467
# INFO:tensorflow:loss = 7.2126, step = 59001 (57.982 sec)
# INFO:tensorflow:global_step/sec: 1.76381
# INFO:tensorflow:loss = 8.283219, step = 59101 (56.696 sec)
# INFO:tensorflow:global_step/sec: 1.76346
# INFO:tensorflow:loss = 7.0480404, step = 59201 (56.706 sec)
# INFO:tensorflow:global_step/sec: 1.76367
# INFO:tensorflow:loss = 7.366996, step = 59301 (56.700 sec)
# INFO:tensorflow:global_step/sec: 1.76448
# INFO:tensorflow:loss = 7.4049377, step = 59401 (56.674 sec)
# INFO:tensorflow:Saving checkpoints for 59500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72342
# INFO:tensorflow:loss = 7.342829, step = 59501 (58.024 sec)
# INFO:tensorflow:global_step/sec: 1.76391
# INFO:tensorflow:loss = 6.8621454, step = 59601 (56.692 sec)
# INFO:tensorflow:global_step/sec: 1.76406
# INFO:tensorflow:loss = 6.996724, step = 59701 (56.688 sec)
# INFO:tensorflow:global_step/sec: 1.76396
# INFO:tensorflow:loss = 7.7036567, step = 59801 (56.691 sec)
# INFO:tensorflow:global_step/sec: 1.76374
# INFO:tensorflow:loss = 8.223148, step = 59901 (56.698 sec)
# INFO:tensorflow:Saving checkpoints for 60000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72173
# INFO:tensorflow:loss = 7.9180183, step = 60001 (58.081 sec)
# INFO:tensorflow:global_step/sec: 1.76504
# INFO:tensorflow:loss = 6.7262955, step = 60101 (56.656 sec)
# INFO:tensorflow:global_step/sec: 1.76372
# INFO:tensorflow:loss = 8.9412365, step = 60201 (56.698 sec)
# INFO:tensorflow:global_step/sec: 1.76482
# INFO:tensorflow:loss = 6.6089044, step = 60301 (56.663 sec)
# INFO:tensorflow:global_step/sec: 1.75389
# INFO:tensorflow:loss = 7.25307, step = 60401 (57.030 sec)
# INFO:tensorflow:Saving checkpoints for 60500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72115
# INFO:tensorflow:loss = 8.544617, step = 60501 (58.087 sec)
# INFO:tensorflow:global_step/sec: 1.76364
# INFO:tensorflow:loss = 7.173376, step = 60601 (56.701 sec)
# INFO:tensorflow:global_step/sec: 1.76434
# INFO:tensorflow:loss = 6.910833, step = 60701 (56.679 sec)
# INFO:tensorflow:global_step/sec: 1.76401
# INFO:tensorflow:loss = 7.2522306, step = 60801 (56.689 sec)
# INFO:tensorflow:global_step/sec: 1.76466
# INFO:tensorflow:loss = 6.562271, step = 60901 (56.668 sec)
# INFO:tensorflow:Saving checkpoints for 61000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72441
# INFO:tensorflow:loss = 6.565466, step = 61001 (57.991 sec)
# INFO:tensorflow:global_step/sec: 1.76396
# INFO:tensorflow:loss = 5.389415, step = 61101 (56.691 sec)
# INFO:tensorflow:global_step/sec: 1.76364
# INFO:tensorflow:loss = 7.500133, step = 61201 (56.701 sec)
# INFO:tensorflow:global_step/sec: 1.76488
# INFO:tensorflow:loss = 7.4053435, step = 61301 (56.661 sec)
# INFO:tensorflow:global_step/sec: 1.76449
# INFO:tensorflow:loss = 6.2403326, step = 61401 (56.674 sec)
# INFO:tensorflow:Saving checkpoints for 61500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72067
# INFO:tensorflow:loss = 9.295235, step = 61501 (58.117 sec)
# INFO:tensorflow:global_step/sec: 1.76274
# INFO:tensorflow:loss = 7.453431, step = 61601 (56.730 sec)
# INFO:tensorflow:global_step/sec: 1.76478
# INFO:tensorflow:loss = 7.132374, step = 61701 (56.664 sec)
# INFO:tensorflow:global_step/sec: 1.76329
# INFO:tensorflow:loss = 7.7727685, step = 61801 (56.712 sec)
# INFO:tensorflow:global_step/sec: 1.76297
# INFO:tensorflow:loss = 8.386823, step = 61901 (56.722 sec)
# INFO:tensorflow:Saving checkpoints for 62000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72066
# INFO:tensorflow:loss = 6.595264, step = 62001 (58.118 sec)
# INFO:tensorflow:global_step/sec: 1.76455
# INFO:tensorflow:loss = 7.5419908, step = 62101 (56.672 sec)
# INFO:tensorflow:global_step/sec: 1.7629
# INFO:tensorflow:loss = 8.752579, step = 62201 (56.725 sec)
# INFO:tensorflow:global_step/sec: 1.7623
# INFO:tensorflow:loss = 6.8792872, step = 62301 (56.744 sec)
# INFO:tensorflow:global_step/sec: 1.76377
# INFO:tensorflow:loss = 8.626303, step = 62401 (56.697 sec)
# INFO:tensorflow:Saving checkpoints for 62500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72426
# INFO:tensorflow:loss = 7.432608, step = 62501 (57.996 sec)
# INFO:tensorflow:global_step/sec: 1.76444
# INFO:tensorflow:loss = 7.195633, step = 62601 (56.675 sec)
# INFO:tensorflow:global_step/sec: 1.76388
# INFO:tensorflow:loss = 7.498726, step = 62701 (56.693 sec)
# INFO:tensorflow:global_step/sec: 1.76492
# INFO:tensorflow:loss = 7.0693145, step = 62801 (56.660 sec)
# INFO:tensorflow:global_step/sec: 1.75199
# INFO:tensorflow:loss = 7.556483, step = 62901 (57.078 sec)
# INFO:tensorflow:Saving checkpoints for 63000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72269
# INFO:tensorflow:loss = 7.3928733, step = 63001 (58.048 sec)
# INFO:tensorflow:global_step/sec: 1.76428
# INFO:tensorflow:loss = 7.790218, step = 63101 (56.681 sec)
# INFO:tensorflow:global_step/sec: 1.76273
# INFO:tensorflow:loss = 6.879475, step = 63201 (56.730 sec)
# INFO:tensorflow:global_step/sec: 1.76329
# INFO:tensorflow:loss = 7.1453886, step = 63301 (56.712 sec)
# INFO:tensorflow:global_step/sec: 1.76354
# INFO:tensorflow:loss = 7.901086, step = 63401 (56.704 sec)
# INFO:tensorflow:Saving checkpoints for 63500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71951
# INFO:tensorflow:loss = 7.9054375, step = 63501 (58.156 sec)
# INFO:tensorflow:global_step/sec: 1.76528
# INFO:tensorflow:loss = 7.4210114, step = 63601 (56.648 sec)
# INFO:tensorflow:global_step/sec: 1.76407
# INFO:tensorflow:loss = 6.203276, step = 63701 (56.687 sec)
# INFO:tensorflow:global_step/sec: 1.76341
# INFO:tensorflow:loss = 7.3560133, step = 63801 (56.708 sec)
# INFO:tensorflow:global_step/sec: 1.76236
# INFO:tensorflow:loss = 7.67742, step = 63901 (56.742 sec)
# INFO:tensorflow:Saving checkpoints for 64000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72019
# INFO:tensorflow:loss = 8.005918, step = 64001 (58.133 sec)
# INFO:tensorflow:global_step/sec: 1.76385
# INFO:tensorflow:loss = 7.2829275, step = 64101 (56.694 sec)
# INFO:tensorflow:global_step/sec: 1.76546
# INFO:tensorflow:loss = 7.94688, step = 64201 (56.642 sec)
# INFO:tensorflow:global_step/sec: 1.76281
# INFO:tensorflow:loss = 7.1744466, step = 64301 (56.728 sec)
# INFO:tensorflow:global_step/sec: 1.76384
# INFO:tensorflow:loss = 7.844663, step = 64401 (56.695 sec)
# INFO:tensorflow:Saving checkpoints for 64500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72519
# INFO:tensorflow:loss = 7.9464974, step = 64501 (57.964 sec)
# INFO:tensorflow:global_step/sec: 1.76317
# INFO:tensorflow:loss = 7.9927263, step = 64601 (56.716 sec)
# INFO:tensorflow:global_step/sec: 1.76407
# INFO:tensorflow:loss = 8.665651, step = 64701 (56.687 sec)
# INFO:tensorflow:global_step/sec: 1.76384
# INFO:tensorflow:loss = 8.130994, step = 64801 (56.695 sec)
# INFO:tensorflow:global_step/sec: 1.76319
# INFO:tensorflow:loss = 7.8990226, step = 64901 (56.716 sec)
# INFO:tensorflow:Saving checkpoints for 65000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72228
# INFO:tensorflow:loss = 9.730624, step = 65001 (58.062 sec)
# INFO:tensorflow:global_step/sec: 1.76404
# INFO:tensorflow:loss = 7.618501, step = 65101 (56.688 sec)
# INFO:tensorflow:global_step/sec: 1.76369
# INFO:tensorflow:loss = 7.1435966, step = 65201 (56.699 sec)
# INFO:tensorflow:global_step/sec: 1.75216
# INFO:tensorflow:loss = 7.0832944, step = 65301 (57.086 sec)
# INFO:tensorflow:global_step/sec: 1.76202
# INFO:tensorflow:loss = 7.8043604, step = 65401 (56.739 sec)
# INFO:tensorflow:Saving checkpoints for 65500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72053
# INFO:tensorflow:loss = 7.5070434, step = 65501 (58.122 sec)
# INFO:tensorflow:global_step/sec: 1.76405
# INFO:tensorflow:loss = 8.147025, step = 65601 (56.688 sec)
# INFO:tensorflow:global_step/sec: 1.76446
# INFO:tensorflow:loss = 7.629622, step = 65701 (56.675 sec)
# INFO:tensorflow:global_step/sec: 1.76429
# INFO:tensorflow:loss = 8.22355, step = 65801 (56.680 sec)
# INFO:tensorflow:global_step/sec: 1.76326
# INFO:tensorflow:loss = 7.971889, step = 65901 (56.713 sec)
# INFO:tensorflow:Saving checkpoints for 66000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72238
# INFO:tensorflow:loss = 8.986861, step = 66001 (58.059 sec)
# INFO:tensorflow:global_step/sec: 1.76401
# INFO:tensorflow:loss = 7.532653, step = 66101 (56.689 sec)
# INFO:tensorflow:global_step/sec: 1.76425
# INFO:tensorflow:loss = 8.963436, step = 66201 (56.682 sec)
# INFO:tensorflow:global_step/sec: 1.76304
# INFO:tensorflow:loss = 7.385794, step = 66301 (56.720 sec)
# INFO:tensorflow:global_step/sec: 1.76395
# INFO:tensorflow:loss = 9.266138, step = 66401 (56.691 sec)
# INFO:tensorflow:Saving checkpoints for 66500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72486
# INFO:tensorflow:loss = 7.2379417, step = 66501 (57.975 sec)
# INFO:tensorflow:global_step/sec: 1.76344
# INFO:tensorflow:loss = 8.069983, step = 66601 (56.707 sec)
# INFO:tensorflow:global_step/sec: 1.76484
# INFO:tensorflow:loss = 9.191012, step = 66701 (56.662 sec)
# INFO:tensorflow:global_step/sec: 1.76213
# INFO:tensorflow:loss = 10.522679, step = 66801 (56.750 sec)
# INFO:tensorflow:global_step/sec: 1.76458
# INFO:tensorflow:loss = 7.819843, step = 66901 (56.670 sec)
# INFO:tensorflow:Saving checkpoints for 67000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72047
# INFO:tensorflow:loss = 8.467874, step = 67001 (58.124 sec)
# INFO:tensorflow:global_step/sec: 1.76479
# INFO:tensorflow:loss = 8.032469, step = 67101 (56.664 sec)
# INFO:tensorflow:global_step/sec: 1.76422
# INFO:tensorflow:loss = 8.609306, step = 67201 (56.682 sec)
# INFO:tensorflow:global_step/sec: 1.76418
# INFO:tensorflow:loss = 8.73419, step = 67301 (56.684 sec)
# INFO:tensorflow:global_step/sec: 1.76372
# INFO:tensorflow:loss = 6.953239, step = 67401 (56.698 sec)
# INFO:tensorflow:Saving checkpoints for 67500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72273
# INFO:tensorflow:loss = 8.213358, step = 67501 (58.047 sec)
# INFO:tensorflow:global_step/sec: 1.76469
# INFO:tensorflow:loss = 9.364358, step = 67601 (56.668 sec)
# INFO:tensorflow:global_step/sec: 1.76416
# INFO:tensorflow:loss = 7.782026, step = 67701 (56.684 sec)
# INFO:tensorflow:global_step/sec: 1.75222
# INFO:tensorflow:loss = 10.032857, step = 67801 (57.071 sec)
# INFO:tensorflow:global_step/sec: 1.76397
# INFO:tensorflow:loss = 8.156305, step = 67901 (56.690 sec)
# INFO:tensorflow:Saving checkpoints for 68000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72494
# INFO:tensorflow:loss = 7.700616, step = 68001 (57.973 sec)
# INFO:tensorflow:global_step/sec: 1.7657
# INFO:tensorflow:loss = 7.9269676, step = 68101 (56.635 sec)
# INFO:tensorflow:global_step/sec: 1.76387
# INFO:tensorflow:loss = 8.067314, step = 68201 (56.694 sec)
# INFO:tensorflow:global_step/sec: 1.76375
# INFO:tensorflow:loss = 8.2623, step = 68301 (56.697 sec)
# INFO:tensorflow:global_step/sec: 1.76375
# INFO:tensorflow:loss = 7.750767, step = 68401 (56.697 sec)
# INFO:tensorflow:Saving checkpoints for 68500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72298
# ...
# INFO:tensorflow:global_step/sec: 1.7645
# INFO:tensorflow:loss = 9.58913, step = 107101 (56.674 sec)
# INFO:tensorflow:global_step/sec: 1.76504
# INFO:tensorflow:loss = 8.41387, step = 107201 (56.655 sec)
# INFO:tensorflow:global_step/sec: 1.76378
# INFO:tensorflow:loss = 10.682079, step = 107301 (56.697 sec)
# INFO:tensorflow:global_step/sec: 1.76504
# INFO:tensorflow:loss = 7.0730395, step = 107401 (56.656 sec)
# INFO:tensorflow:Saving checkpoints for 107500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72543
# INFO:tensorflow:loss = 10.889926, step = 107501 (57.956 sec)
# INFO:tensorflow:global_step/sec: 1.76371
# INFO:tensorflow:loss = 9.292253, step = 107601 (56.699 sec)
# INFO:tensorflow:global_step/sec: 1.76437
# INFO:tensorflow:loss = 7.950452, step = 107701 (56.677 sec)
# INFO:tensorflow:global_step/sec: 1.76404
# INFO:tensorflow:loss = 7.2926755, step = 107801 (56.688 sec)
# INFO:tensorflow:global_step/sec: 1.76431
# INFO:tensorflow:loss = 8.770061, step = 107901 (56.679 sec)
# INFO:tensorflow:Saving checkpoints for 108000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72179
# INFO:tensorflow:loss = 9.062937, step = 108001 (58.079 sec)
# INFO:tensorflow:global_step/sec: 1.76249
# INFO:tensorflow:loss = 9.992356, step = 108101 (56.738 sec)
# INFO:tensorflow:global_step/sec: 1.76409
# INFO:tensorflow:loss = 9.036769, step = 108201 (56.686 sec)
# INFO:tensorflow:global_step/sec: 1.7641
# INFO:tensorflow:loss = 9.10284, step = 108301 (56.686 sec)
# INFO:tensorflow:global_step/sec: 1.76323
# INFO:tensorflow:loss = 9.153017, step = 108401 (56.714 sec)
# INFO:tensorflow:Saving checkpoints for 108500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71931
# INFO:tensorflow:loss = 7.4785852, step = 108501 (58.163 sec)
# INFO:tensorflow:global_step/sec: 1.764
# INFO:tensorflow:loss = 8.584856, step = 108601 (56.689 sec)
# INFO:tensorflow:global_step/sec: 1.76505
# INFO:tensorflow:loss = 9.058788, step = 108701 (56.656 sec)
# INFO:tensorflow:global_step/sec: 1.76425
# INFO:tensorflow:loss = 8.312543, step = 108801 (56.682 sec)
# INFO:tensorflow:global_step/sec: 1.76465
# INFO:tensorflow:loss = 10.219092, step = 108901 (56.669 sec)
# INFO:tensorflow:Saving checkpoints for 109000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72084
# INFO:tensorflow:loss = 10.05327, step = 109001 (58.111 sec)
# INFO:tensorflow:global_step/sec: 1.76476
# INFO:tensorflow:loss = 8.08918, step = 109101 (56.665 sec)
# INFO:tensorflow:global_step/sec: 1.76329
# INFO:tensorflow:loss = 8.273872, step = 109201 (56.712 sec)
# INFO:tensorflow:global_step/sec: 1.76456
# INFO:tensorflow:loss = 8.260069, step = 109301 (56.672 sec)
# INFO:tensorflow:global_step/sec: 1.75251
# INFO:tensorflow:loss = 8.63428, step = 109401 (57.075 sec)
# INFO:tensorflow:Saving checkpoints for 109500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.7241
# INFO:tensorflow:loss = 8.462599, step = 109501 (57.987 sec)
# INFO:tensorflow:global_step/sec: 1.76389
# INFO:tensorflow:loss = 8.735846, step = 109601 (56.693 sec)
# INFO:tensorflow:global_step/sec: 1.76534
# INFO:tensorflow:loss = 7.7480087, step = 109701 (56.647 sec)
# INFO:tensorflow:global_step/sec: 1.76487
# INFO:tensorflow:loss = 9.444929, step = 109801 (56.662 sec)
# INFO:tensorflow:global_step/sec: 1.76383
# INFO:tensorflow:loss = 10.299812, step = 109901 (56.695 sec)
# INFO:tensorflow:Saving checkpoints for 110000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71961
# INFO:tensorflow:loss = 8.658133, step = 110001 (58.153 sec)
# INFO:tensorflow:global_step/sec: 1.76347
# INFO:tensorflow:loss = 9.341064, step = 110101 (56.707 sec)
# INFO:tensorflow:global_step/sec: 1.76373
# INFO:tensorflow:loss = 7.4142017, step = 110201 (56.698 sec)
# INFO:tensorflow:global_step/sec: 1.76383
# INFO:tensorflow:loss = 9.926588, step = 110301 (56.695 sec)
# INFO:tensorflow:global_step/sec: 1.76374
# INFO:tensorflow:loss = 8.907381, step = 110401 (56.697 sec)
# INFO:tensorflow:Saving checkpoints for 110500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72323
# INFO:tensorflow:loss = 10.382664, step = 110501 (58.030 sec)
# INFO:tensorflow:global_step/sec: 1.76422
# INFO:tensorflow:loss = 8.247326, step = 110601 (56.682 sec)
# INFO:tensorflow:global_step/sec: 1.76348
# INFO:tensorflow:loss = 6.298963, step = 110701 (56.706 sec)
# INFO:tensorflow:global_step/sec: 1.76233
# INFO:tensorflow:loss = 8.832874, step = 110801 (56.743 sec)
# INFO:tensorflow:global_step/sec: 1.76381
# INFO:tensorflow:loss = 10.668675, step = 110901 (56.696 sec)
# INFO:tensorflow:Saving checkpoints for 111000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72146
# INFO:tensorflow:loss = 5.406927, step = 111001 (58.090 sec)
# INFO:tensorflow:global_step/sec: 1.76473
# INFO:tensorflow:loss = 6.633912, step = 111101 (56.666 sec)
# INFO:tensorflow:global_step/sec: 1.7627
# INFO:tensorflow:loss = 9.236749, step = 111201 (56.731 sec)
# INFO:tensorflow:global_step/sec: 1.76401
# INFO:tensorflow:loss = 9.364903, step = 111301 (56.689 sec)
# INFO:tensorflow:global_step/sec: 1.76359
# INFO:tensorflow:loss = 8.477496, step = 111401 (56.703 sec)
# INFO:tensorflow:Saving checkpoints for 111500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71978
# INFO:tensorflow:loss = 8.014468, step = 111501 (58.146 sec)
# INFO:tensorflow:global_step/sec: 1.7628
# INFO:tensorflow:loss = 9.552813, step = 111601 (56.728 sec)
# INFO:tensorflow:global_step/sec: 1.76306
# INFO:tensorflow:loss = 9.923782, step = 111701 (56.719 sec)
# INFO:tensorflow:global_step/sec: 1.76207
# INFO:tensorflow:loss = 10.041261, step = 111801 (56.752 sec)
# INFO:tensorflow:global_step/sec: 1.75195
# INFO:tensorflow:loss = 8.423245, step = 111901 (57.079 sec)
# INFO:tensorflow:Saving checkpoints for 112000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71898
# INFO:tensorflow:loss = 8.433207, step = 112001 (58.174 sec)
# INFO:tensorflow:global_step/sec: 1.76101
# INFO:tensorflow:loss = 8.283734, step = 112101 (56.786 sec)
# INFO:tensorflow:global_step/sec: 1.76226
# INFO:tensorflow:loss = 8.364401, step = 112201 (56.745 sec)
# INFO:tensorflow:global_step/sec: 1.76313
# INFO:tensorflow:loss = 8.787001, step = 112301 (56.717 sec)
# INFO:tensorflow:global_step/sec: 1.76307
# INFO:tensorflow:loss = 8.89109, step = 112401 (56.719 sec)
# INFO:tensorflow:Saving checkpoints for 112500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72439
# INFO:tensorflow:loss = 9.199288, step = 112501 (57.992 sec)
# INFO:tensorflow:global_step/sec: 1.76346
# INFO:tensorflow:loss = 9.8093, step = 112601 (56.707 sec)
# INFO:tensorflow:global_step/sec: 1.76256
# INFO:tensorflow:loss = 11.9746685, step = 112701 (56.736 sec)
# INFO:tensorflow:global_step/sec: 1.76157
# INFO:tensorflow:loss = 9.295657, step = 112801 (56.768 sec)
# INFO:tensorflow:global_step/sec: 1.76313
# INFO:tensorflow:loss = 7.5056024, step = 112901 (56.717 sec)
# INFO:tensorflow:Saving checkpoints for 113000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.7225
# INFO:tensorflow:loss = 9.241611, step = 113001 (58.055 sec)
# INFO:tensorflow:global_step/sec: 1.76377
# INFO:tensorflow:loss = 9.544763, step = 113101 (56.697 sec)
# INFO:tensorflow:global_step/sec: 1.76351
# INFO:tensorflow:loss = 9.730476, step = 113201 (56.705 sec)
# INFO:tensorflow:global_step/sec: 1.76304
# INFO:tensorflow:loss = 8.655949, step = 113301 (56.720 sec)
# INFO:tensorflow:global_step/sec: 1.76336
# INFO:tensorflow:loss = 8.86189, step = 113401 (56.710 sec)
# INFO:tensorflow:Saving checkpoints for 113500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71991
# INFO:tensorflow:loss = 6.776365, step = 113501 (58.142 sec)
# INFO:tensorflow:global_step/sec: 1.76403
# INFO:tensorflow:loss = 8.189271, step = 113601 (56.688 sec)
# INFO:tensorflow:global_step/sec: 1.76302
# INFO:tensorflow:loss = 7.841163, step = 113701 (56.721 sec)
# INFO:tensorflow:global_step/sec: 1.77115
# INFO:tensorflow:loss = 8.362217, step = 113801 (56.460 sec)
# INFO:tensorflow:global_step/sec: 1.764
# INFO:tensorflow:loss = 9.188285, step = 113901 (56.689 sec)
# INFO:tensorflow:Saving checkpoints for 114000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72133
# INFO:tensorflow:loss = 7.8911715, step = 114001 (58.095 sec)
# INFO:tensorflow:global_step/sec: 1.76468
# INFO:tensorflow:loss = 9.331068, step = 114101 (56.667 sec)
# INFO:tensorflow:global_step/sec: 1.76464
# INFO:tensorflow:loss = 8.774721, step = 114201 (56.669 sec)
# INFO:tensorflow:global_step/sec: 1.75327
# INFO:tensorflow:loss = 9.473632, step = 114301 (57.051 sec)
# INFO:tensorflow:global_step/sec: 1.76301
# INFO:tensorflow:loss = 9.657685, step = 114401 (56.706 sec)
# INFO:tensorflow:Saving checkpoints for 114500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72506
# INFO:tensorflow:loss = 8.2023, step = 114501 (57.969 sec)
# INFO:tensorflow:global_step/sec: 1.76539
# INFO:tensorflow:loss = 8.346905, step = 114601 (56.645 sec)
# INFO:tensorflow:global_step/sec: 1.76341
# INFO:tensorflow:loss = 2.449218, step = 114701 (56.708 sec)
# INFO:tensorflow:global_step/sec: 1.76378
# INFO:tensorflow:loss = 6.5881987, step = 114801 (56.696 sec)
# INFO:tensorflow:global_step/sec: 1.76319
# INFO:tensorflow:loss = 8.1519165, step = 114901 (56.715 sec)
# INFO:tensorflow:Saving checkpoints for 115000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72028
# INFO:tensorflow:loss = 9.620923, step = 115001 (58.130 sec)
# INFO:tensorflow:global_step/sec: 1.76458
# INFO:tensorflow:loss = 8.6933, step = 115101 (56.671 sec)
# INFO:tensorflow:global_step/sec: 1.76467
# INFO:tensorflow:loss = 8.169308, step = 115201 (56.668 sec)
# INFO:tensorflow:global_step/sec: 1.76466
# INFO:tensorflow:loss = 8.181926, step = 115301 (56.668 sec)
# INFO:tensorflow:global_step/sec: 1.76393
# INFO:tensorflow:loss = 7.662358, step = 115401 (56.692 sec)
# INFO:tensorflow:Saving checkpoints for 115500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72515
# INFO:tensorflow:loss = 9.62037, step = 115501 (57.966 sec)
# INFO:tensorflow:global_step/sec: 1.76317
# INFO:tensorflow:loss = 9.748442, step = 115601 (56.716 sec)
# INFO:tensorflow:global_step/sec: 1.76441
# INFO:tensorflow:loss = 8.201695, step = 115701 (56.676 sec)
# INFO:tensorflow:global_step/sec: 1.76414
# INFO:tensorflow:loss = 9.652988, step = 115801 (56.685 sec)
# INFO:tensorflow:global_step/sec: 1.76405
# INFO:tensorflow:loss = 9.167886, step = 115901 (56.688 sec)
# INFO:tensorflow:Saving checkpoints for 116000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72211
# INFO:tensorflow:loss = 9.489188, step = 116001 (58.068 sec)
# INFO:tensorflow:global_step/sec: 1.7645
# INFO:tensorflow:loss = 9.004629, step = 116101 (56.673 sec)
# INFO:tensorflow:global_step/sec: 1.76457
# INFO:tensorflow:loss = 14.992952, step = 116201 (56.671 sec)
# INFO:tensorflow:global_step/sec: 1.76302
# INFO:tensorflow:loss = 8.217261, step = 116301 (56.721 sec)
# INFO:tensorflow:global_step/sec: 1.76377
# INFO:tensorflow:loss = 8.427233, step = 116401 (56.696 sec)
# INFO:tensorflow:Saving checkpoints for 116500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71955
# INFO:tensorflow:loss = 14.642582, step = 116501 (58.155 sec)
# INFO:tensorflow:global_step/sec: 1.76306
# INFO:tensorflow:loss = 15.481279, step = 116601 (56.720 sec)
# INFO:tensorflow:global_step/sec: 1.76387
# INFO:tensorflow:loss = 10.1866255, step = 116701 (56.693 sec)
# INFO:tensorflow:global_step/sec: 1.75222
# INFO:tensorflow:loss = 9.106012, step = 116801 (57.071 sec)
# INFO:tensorflow:global_step/sec: 1.76443
# INFO:tensorflow:loss = 11.344303, step = 116901 (56.675 sec)
# INFO:tensorflow:Saving checkpoints for 117000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72054
# INFO:tensorflow:loss = 8.749406, step = 117001 (58.121 sec)
# INFO:tensorflow:global_step/sec: 1.7611
# INFO:tensorflow:loss = 6.342802, step = 117101 (56.782 sec)
# INFO:tensorflow:global_step/sec: 1.7639
# INFO:tensorflow:loss = 10.313604, step = 117201 (56.693 sec)
# INFO:tensorflow:global_step/sec: 1.76337
# INFO:tensorflow:loss = 8.83838, step = 117301 (56.709 sec)
# INFO:tensorflow:global_step/sec: 1.761
# INFO:tensorflow:loss = 9.424895, step = 117401 (56.786 sec)
# INFO:tensorflow:Saving checkpoints for 117500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.7257
# INFO:tensorflow:loss = 7.0408635, step = 117501 (57.948 sec)
# INFO:tensorflow:global_step/sec: 1.76244
# INFO:tensorflow:loss = 7.7011323, step = 117601 (56.740 sec)
# INFO:tensorflow:global_step/sec: 1.76452
# INFO:tensorflow:loss = 8.33817, step = 117701 (56.673 sec)
# INFO:tensorflow:global_step/sec: 1.76285
# INFO:tensorflow:loss = 8.14049, step = 117801 (56.726 sec)
# INFO:tensorflow:global_step/sec: 1.76253
# INFO:tensorflow:loss = 5.667445, step = 117901 (56.736 sec)
# INFO:tensorflow:Saving checkpoints for 118000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72171
# INFO:tensorflow:loss = 8.972177, step = 118001 (58.082 sec)
# INFO:tensorflow:global_step/sec: 1.76499
# INFO:tensorflow:loss = 10.269398, step = 118101 (56.658 sec)
# INFO:tensorflow:global_step/sec: 1.76306
# INFO:tensorflow:loss = 8.936125, step = 118201 (56.719 sec)
# INFO:tensorflow:global_step/sec: 1.76346
# INFO:tensorflow:loss = 8.465619, step = 118301 (56.707 sec)
# INFO:tensorflow:global_step/sec: 1.76436
# INFO:tensorflow:loss = 8.8963375, step = 118401 (56.678 sec)
# INFO:tensorflow:Saving checkpoints for 118500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71979
# INFO:tensorflow:loss = 7.06242, step = 118501 (58.147 sec)
# INFO:tensorflow:global_step/sec: 1.76356
# INFO:tensorflow:loss = 8.546037, step = 118601 (56.703 sec)
# INFO:tensorflow:global_step/sec: 1.76328
# INFO:tensorflow:loss = 8.654151, step = 118701 (56.713 sec)
# INFO:tensorflow:global_step/sec: 1.76291
# INFO:tensorflow:loss = 10.550975, step = 118801 (56.724 sec)
# INFO:tensorflow:global_step/sec: 1.76388
# INFO:tensorflow:loss = 9.991687, step = 118901 (56.693 sec)
# INFO:tensorflow:Saving checkpoints for 119000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72224
# INFO:tensorflow:loss = 8.84394, step = 119001 (58.064 sec)
# INFO:tensorflow:global_step/sec: 1.76486
# INFO:tensorflow:loss = 9.112631, step = 119101 (56.662 sec)
# INFO:tensorflow:global_step/sec: 1.75318
# INFO:tensorflow:loss = 10.005021, step = 119201 (57.053 sec)
# INFO:tensorflow:global_step/sec: 1.7631
# INFO:tensorflow:loss = 7.9181724, step = 119301 (56.705 sec)
# INFO:tensorflow:global_step/sec: 1.76308
# INFO:tensorflow:loss = 7.982425, step = 119401 (56.719 sec)
# INFO:tensorflow:Saving checkpoints for 119500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72586
# INFO:tensorflow:loss = 9.427057, step = 119501 (57.942 sec)
# INFO:tensorflow:global_step/sec: 1.76313
# INFO:tensorflow:loss = 12.128765, step = 119601 (56.718 sec)
# INFO:tensorflow:global_step/sec: 1.76343
# INFO:tensorflow:loss = 9.217159, step = 119701 (56.708 sec)
# INFO:tensorflow:global_step/sec: 1.76365
# INFO:tensorflow:loss = 9.053228, step = 119801 (56.701 sec)
# INFO:tensorflow:global_step/sec: 1.76346
# INFO:tensorflow:loss = 10.227643, step = 119901 (56.706 sec)
# INFO:tensorflow:Saving checkpoints for 120000 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.71976
# INFO:tensorflow:loss = 10.63669, step = 120001 (58.148 sec)
# INFO:tensorflow:global_step/sec: 1.7657
# INFO:tensorflow:loss = 7.913427, step = 120101 (56.635 sec)
# INFO:tensorflow:global_step/sec: 1.76453
# INFO:tensorflow:loss = 6.285139, step = 120201 (56.672 sec)
# INFO:tensorflow:global_step/sec: 1.76287
# INFO:tensorflow:loss = 6.956264, step = 120301 (56.726 sec)
# INFO:tensorflow:global_step/sec: 1.76435
# INFO:tensorflow:loss = 6.093244, step = 120401 (56.678 sec)
# INFO:tensorflow:Saving checkpoints for 120500 into ../logs/model.ckpt.
# INFO:tensorflow:global_step/sec: 1.72399
# INFO:tensorflow:loss = 6.3243, step = 120501 (58.005 sec)
# INFO:tensorflow:global_step/sec: 1.76394
# INFO:tensorflow:loss = 7.4976172, step = 120601 (56.692 sec)
# INFO:tensorflow:global_step/sec: 1.76385
# INFO:tensorflow:loss = 7.4489207, step = 120701 (56.694 sec)
# INFO:tensorflow:global_step/sec: 1.76418
# INFO:tensorflow:loss = 6.9937167, step = 120801 (56.684 sec)
# INFO:tensorflow:Saving checkpoints for 120844 into ../logs/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.312162.

# %% [markdown]
# ## NOTES
#
# [1]: [The GAN Landscape: Losses, Architectures, Regularization, and Normalization](https://arxiv.org/abs/1807.04720v1), which in our opinion is one of the most thorough scientific studies on GANs out there, suggests that `Spectral Normalization` is the real big deal and that `BatchNorm` actually hurt performance if applied to the Discriminator. We still decided to go with the classic formulation of DCGAN as not to overtax you with theoretical discussions. We leave the implementation of the `Spectral Normalization`(and SNGAN) to you as an exercise. On the theoretical treating of `BatchNorm` we recommend a back to back reading of [Batch Normalization: Accelerating Deep Network Training by Reducing Internal Covariate Shift](https://arxiv.org/abs/1502.03167), [Understanding Batch Normalization](https://arxiv.org/abs/1806.02375v1), [How Does Batch Normalization Help Optimization? (No, It Is Not About Internal Covariate Shift)](https://arxiv.org/abs/1805.11604)

# %% [markdown]
# ## Links
#
# Generative Adversarial Networks : https://arxiv.org/abs/1406.2661
#
# really-awesome-gan : https://github.com/nightrome/really-awesome-gan
#
# DCGAN : https://arxiv.org/abs/1511.06434
#
# Deconvolution and Checkerboard Artifacts : https://distill.pub/2016/deconv-checkerboard/
#
# TFGAN MNIST GAN Example : https://github.com/tensorflow/models/tree/master/research/gan/mnist_estimator
